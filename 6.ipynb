# %%
import os
import sys
from PIL import Image
from PIL import ImageEnhance
import numpy as np

# %%
im = Image.open("data/6.jpg")
imRot = im.rotate(90, expand=1)

# %%
im_ = imRot.split()

# %%
im_[0]
# Out:
# <PIL.Image.Image image mode=L size=480x640 at 0x105C615C0>

# %%
im_[1]
# Out:
# <PIL.Image.Image image mode=L size=480x640 at 0x105C61E10>

# %%
im_[2]
# Out:
# <PIL.Image.Image image mode=L size=480x640 at 0x105C61128>

# %%
Rband = np.array(im_[0])
Gband = np.array(im_[1])
Bband = np.array(im_[2])

# %%
for i,j in zip(Rband, Gband):
    pass
